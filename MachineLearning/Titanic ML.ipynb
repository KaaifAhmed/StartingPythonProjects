# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_excel('titanic3.xls')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked
# ...

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.0000      0      0   24160  211.3375       B5        S
# 1   0.9167      1      2  113781  151.5500  C22 C26        S
# 2   2.0000      1      2  113781  151.5500  C22 C26        S
# 3  30.0000      1      2  113781  151.5500  C22 C26        S
# 4  25.0000      1      2  113781  151.5500  C22 C26        S

# %%
df.shape
# Out:
# (1309, 11)

# %%
df.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin       1014
# embarked       2
# dtype: int64

# %%
df.drop('cabin', axis=1)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
# df.head(50)

# %%
# testdf = df.drop([1,2])

# %%
# testdf

# %%
# testdf.loc[1]

# %%
df[df['fare'].isnull()]
# Out:
#       pclass  survived                name   sex   age  sibsp  parch ticket  \
# 1225       3         0  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#       fare cabin embarked
# 1225   NaN   NaN        S

# %%
df['sex'].replace('male', 0)
# Out:
# 0       female
# 1            0
# 2       female
# 3            0
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306         0
# 1307         0
# 1308         0
# Name: sex, Length: 1309, dtype: object

# %%
# df[df['age'] > 25]

# %%
### Dropping unnecessary columns

# %%
df.drop(1225, inplace=True)
df['fare'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked
# ...

# %%
# df.drop(columns=['name', 'ticket', 'cabin'], axis=1, inplace=True)

# %%
### Filling null elements

# %%
df.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin       1013
# embarked       2
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(), inplace=True)
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin       1013
# embarked       0
# dtype: int64

# %%
# df['embarked'].mode()

# %%
### Transforming String Categories into numbers

# %%
df.replace({'sex':{'male':0, 'female':1}, 'embarked':{'S':0, 'C':1, 'Q':2}}, inplace=True)

# %%
df
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    1
# 1          1         1                   Allison, Master. Hudson Trevor    0
# 2          1         0                     Allison, Miss. Helen Loraine    1
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    1
# 1305       3         0                            Zabour, Miss. Thamine    1
# 1306       3         0                        Zakarian, Mr. Mapriededer    0
# 1307       3         0                              Zakarian, Mr. Ortin    0
# 1308       3         0                               Zimmerman, Mr. Leo    0
#
# ...

# %%
### Splitting data into features and target

# %%
X = df.drop(['name', 'ticket', 'fare', 'cabin', 'survived'], axis=1)
Y = df['survived']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
X
# Out:
#       pclass  sex        age  sibsp  parch  embarked
# 0          1    1  29.000000      0      0         0
# 1          1    0   0.916700      1      2         0
# 2          1    1   2.000000      1      2         0
# 3          1    0  30.000000      1      2         0
# 4          1    1  25.000000      1      2         0
# ...      ...  ...        ...    ...    ...       ...
# 1304       3    1  14.500000      1      0         1
# 1305       3    1  29.851834      1      0         1
# 1306       3    0  26.500000      0      0         1
# 1307       3    0  27.000000      0      0         1
# 1308       3    0  29.000000      0      0         0
#
# [1308 rows x 6 columns]

# %%
### Applying the model

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
### Checking The Accuracy

# %%
prediction = model.predict(x_test)

# %%
pd.DataFrame({'Original':y_test, 'Predicited':prediction})
# Out:
#      Original  Predicited
# 201         0           0
# 115         0           0
# 255         1           1
# 730         0           0
# 195         1           1
# ..        ...         ...
# 414         0           0
# 418         0           0
# 301         0           0
# 496         0           0
# 315         1           1
#
# [262 rows x 2 columns]

# %%
model.score(x_test, y_test)
# Out:
# 0.8473282442748091

# %%
0.847328244274809*100
# Out:
# 84.7328244274809

# %%
# The Accuracy Is 84.732
